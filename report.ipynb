# %%
import pandas as pd
import json

# %%
with open("./agents/dqn_weights/dqn_market-maker-v0_log.json") as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#          loss       mae    mean_q  episode_reward  nb_episode_steps  nb_steps  \
# 0    0.070387  0.262994  0.211590      -11.337011               948       948
# 1    0.012340  0.323257  0.069105      -14.161123               775      1723
# 2    0.004170  0.340966  0.008145      -10.881015               814      2537
# 3    0.002232  0.351093 -0.007035      -11.588960               852      3389
# 4    0.002043  0.355787 -0.009369      -14.306915               825      4214
# ..        ...       ...       ...             ...               ...       ...
# 202  0.001522  1.381232  1.557438        7.025358               947    177111
# 203  0.001452  1.380240  1.556705        0.523138               780    177891
# 204  0.001516  1.396104  1.572138        5.638640               857    178748
# 205  0.001473  1.401870  1.580347       -0.313278               871    179619
# 206  0.001465  1.410892  1.588955       -2.270883               958    180577
#
#      episode   duration
# ...

# %%
ax = df.loc[:, "episode_reward"].plot(figsize=(10,7))
ax.set_xlabel("Number of episodes")
ax.set_ylabel("Episode Rewards")
# Out:
# Text(0, 0.5, 'Episode Rewards')

# %%
df.loc[:, "episode_reward"].plot()
# Out:
# <AxesSubplot:>
