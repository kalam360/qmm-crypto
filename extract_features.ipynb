# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from data_store.database.simulator import Simulator
from configurations import TIMEZONE
from datetime import datetime as dt

# %%
import pandas as pd

# %%
sim = Simulator()
start_time = dt.now(tz= TIMEZONE)
query = {
    "ccy": ['BTC-USD'],
    "start_date": 20220718,
    "end_date": 20220719
}
sim.extract_features(query=query)
# Out:
# [2022-07-18 05:54:25,963] init_db_connection for None...
# [2022-07-18 05:54:25,963] Connecting to mongo: localhost (localhost)
# [2022-07-18 05:54:25,968]
# Getting ['BTC-USD'] data from Arctic Tick Store...
# [2022-07-18 05:54:25,972] Simulator._query_arctic() thew an exception:
# No Data found for ['BTC-USD'] in range: [2022-07-18 00:00:00-04:00, 2022-07-19 00:00:00-04:00]
# [2022-07-18 05:54:25,973]
# Nothing returned from Arctic for the query: {'ccy': ['BTC-USD'], 'start_date': 20220718, 'end_date': 20220719}
# ...Exiting...
# [2022-07-18 05:54:25,974] Query returned no data: {'ccy': ['BTC-USD'], 'start_date': 20220718, 'end_date': 20220719}
# [2022-07-18 05:54:25,975] ***
# Simulator.extract_features() executed in 0 seconds
# ***

# %%
df = pd.read_csv("./data_store/database/data_exports/BTC-USD_2022-07-13.csv.xz", index_col="system_time")

# %%
len(df)
# Out:
# 19923

# %%
split_index = int(.7*len(df))

# %%
train_df = df.iloc[:split_index, :]
test_df = df.iloc[split_index:, :]

# %%
train_df.to_csv("./data_store/database/data_exports/train_BTC-USD_2022-07-13.csv.xz")
test_df.to_csv("./data_store/database/data_exports/test_BTC-USD_2022-07-13.csv.xz")

# %%
train_df
# Out:
#                                    midpoint  spread           buys  \
# system_time
# 2022-07-13 09:42:59.672043+00:00  19770.230    0.38       0.000000
# 2022-07-13 09:43:00.672043+00:00  19770.230    0.38       0.000000
# 2022-07-13 09:43:01.672043+00:00  19770.230    0.38       0.000000
# 2022-07-13 09:43:02.672043+00:00  19770.230    0.38       0.000000
# 2022-07-13 09:43:03.672043+00:00  19770.230    0.38       0.000000
# ...                                     ...     ...            ...
# 2022-07-13 13:35:20.672043+00:00  19014.200    4.76    2519.921931
# 2022-07-13 13:35:21.672043+00:00  19023.050    1.38   18051.972367
# 2022-07-13 13:35:22.672043+00:00  19022.620    4.46  111240.799588
# 2022-07-13 13:35:23.672043+00:00  19028.895    2.19    9738.088749
# 2022-07-13 13:35:24.672043+00:00  19035.665    1.89   11923.167503
#
#                                          sells  bids_distance_0  \
# system_time
# 2022-07-13 09:42:59.672043+00:00      0.000000        -0.000010
# ...
